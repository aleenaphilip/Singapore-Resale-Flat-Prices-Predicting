# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv(r"C:\Users\aleenaphilip\OneDrive - St John's National Academy of Health Sciences\Desktop\Data Science\Project_6_Singapore_resale\ResaleFlatPricesBasedonApprovalDate19901999.csv")
df2 = pd.read_csv(r"C:\Users\aleenaphilip\OneDrive - St John's National Academy of Health Sciences\Desktop\Data Science\Project_6_Singapore_resale\ResaleFlatPricesBasedonApprovalDate2000Feb2012.csv")
df3 = pd.read_csv(r"C:\Users\aleenaphilip\OneDrive - St John's National Academy of Health Sciences\Desktop\Data Science\Project_6_Singapore_resale\ResaleFlatPricesBasedonRegistrationDateFromJan2015toDec2016.csv")
df4 = pd.read_csv(r"C:\Users\aleenaphilip\OneDrive - St John's National Academy of Health Sciences\Desktop\Data Science\Project_6_Singapore_resale\ResaleFlatPricesBasedonRegistrationDateFromMar2012toDec2014.csv")
df5 = pd.read_csv(r"C:\Users\aleenaphilip\OneDrive - St John's National Academy of Health Sciences\Desktop\Data Science\Project_6_Singapore_resale\ResaleflatpricesbasedonregistrationdatefromJan2017onwards.csv")

# %% [raw]
# Importing and Reading Combined Data

# %%
# merging all the datasets
df = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)

# %%
df
# Out:
#           month        town  flat_type block       street_name storey_range  \
# 0       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4       1990-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
# ...         ...         ...        ...   ...               ...          ...
# 921091  2024-03      YISHUN     5 ROOM   637      YISHUN ST 61     10 TO 12
# 921092  2024-03      YISHUN     5 ROOM   607      YISHUN ST 61     01 TO 03
# 921093  2024-03      YISHUN     5 ROOM   841      YISHUN ST 81     07 TO 09
# 921094  2024-03      YISHUN  EXECUTIVE   791      YISHUN AVE 2     10 TO 12
# 921095  2024-03      YISHUN  EXECUTIVE   606      YISHUN ST 61     07 TO 09
#
# ...

# %%
df.dtypes
# Out:
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price           float64
# remaining_lease         object
# dtype: object

# %%
df.isnull().sum()
# Out:
# month                       0
# town                        0
# flat_type                   0
# block                       0
# street_name                 0
# storey_range                0
# floor_area_sqm              0
# flat_model                  0
# lease_commence_date         0
# resale_price                0
# remaining_lease        709050
# dtype: int64

# %% [raw]
# Minor Data Preprocessing for Combined Data

# %%
import statistics

# %%
def get_median(x):
    split_list = x.split(' TO ')
    float_list = [float(i) for i in split_list]
    median = statistics.median(float_list)
    return median

# %%
df['storey_median'] = df['storey_range'].apply(lambda x: get_median(x))
df
# Out:
#           month        town  flat_type block       street_name storey_range  \
# 0       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4       1990-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
# ...         ...         ...        ...   ...               ...          ...
# 921091  2024-03      YISHUN     5 ROOM   637      YISHUN ST 61     10 TO 12
# 921092  2024-03      YISHUN     5 ROOM   607      YISHUN ST 61     01 TO 03
# 921093  2024-03      YISHUN     5 ROOM   841      YISHUN ST 81     07 TO 09
# 921094  2024-03      YISHUN  EXECUTIVE   791      YISHUN AVE 2     10 TO 12
# 921095  2024-03      YISHUN  EXECUTIVE   606      YISHUN ST 61     07 TO 09
#
# ...

# %%
scope_df = df[['floor_area_sqm','storey_median','resale_price']]
scope_df
# Out:
#         floor_area_sqm  storey_median  resale_price
# 0                 31.0           11.0        9000.0
# 1                 31.0            5.0        6000.0
# 2                 31.0           11.0        8000.0
# 3                 31.0            8.0        6000.0
# 4                 73.0            5.0       47200.0
# ...                ...            ...           ...
# 921091           121.0           11.0      680000.0
# 921092           121.0            2.0      613000.0
# 921093           122.0            8.0      745000.0
# 921094           146.0           11.0      851888.0
# 921095           142.0            8.0      780000.0
#
# [921096 rows x 3 columns]

# %%
scope_df = scope_df.drop_duplicates()
scope_df
# Out:
#         floor_area_sqm  storey_median  resale_price
# 0                 31.0           11.0        9000.0
# 1                 31.0            5.0        6000.0
# 2                 31.0           11.0        8000.0
# 3                 31.0            8.0        6000.0
# 4                 73.0            5.0       47200.0
# ...                ...            ...           ...
# 921047            92.0            2.0      507000.0
# 921081           112.0            5.0      663000.0
# 921082           127.0            8.0      700000.0
# 921086           132.0            5.0      658000.0
# 921094           146.0           11.0      851888.0
#
# [241229 rows x 3 columns]

# %% [raw]
# Checking and Handling for Skewness in the Data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# List of columns(continuous variables) for finding skewness
col = ['floor_area_sqm','storey_median','resale_price']

for i in col:
    plt.figure(figsize=(8, 6))  
    sns.boxplot(data=df, x=i)
    plt.title(f'Boxplot of {i}')
    plt.xlabel(i)
    plt.show()

# %%
#!pip install seaborn

# %%
df_s = scope_df

# %%
# Apply a logarithmic transformation to the required columns only.
# One need to apply it and check, in some cases it will handle the skewness, and in other cases it might not have a great 
                                                                # effect on the data, so no need to apply for that columns
    
df_s['floor_area_sqm'] = np.log(df_s['floor_area_sqm'])
sns.boxplot(x='floor_area_sqm', data=df_s)
plt.show()

df_s['storey_median'] = np.log(df_s['storey_median'])
sns.boxplot(x='storey_median', data=df_s)
plt.show()

df_s['resale_price'] = np.log(df_s['resale_price'])
sns.boxplot(x='resale_price', data=df_s)
plt.show()

# %%
df_s.dtypes
# Out:
# floor_area_sqm    float64
# storey_median     float64
# resale_price      float64
# dtype: object

# %% [raw]
# Visualization among different columns using Correlation Matrix

# %%
import seaborn as sns

corrMatrix = df_s.corr()
plt.figure(figsize=(15, 10))
plt.title("Correlation Heatmap")
sns.heatmap(
    corrMatrix, 
    xticklabels=corrMatrix.columns,
    yticklabels=corrMatrix.columns,
    cmap='RdBu', 
    annot=True
)
# Out:
# <Axes: title={'center': 'Correlation Heatmap'}>

# %% [markdown]
# Encoding Data

# %%
from sklearn.preprocessing import StandardScaler

X=df_s[['floor_area_sqm','storey_median']]
y=df_s['resale_price']

# Normalizing the encoded data
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
#!pip install scikit-learn

# %%
test_dataframe = pd.DataFrame(X)
test_dataframe
# Out:
#                0         1
# 0      -3.695329  0.559079
# 1      -3.695329 -0.501805
# 2      -3.695329  0.559079
# 3      -3.695329  0.130593
# 4      -0.920187 -0.501805
# ...          ...       ...
# 241224 -0.170635 -1.734692
# 241225  0.466746 -0.501805
# 241226  0.874001  0.130593
# 241227  0.999121 -0.501805
# 241228  1.325748  0.559079
#
# [241229 rows x 2 columns]

# %% [markdown]
# Splitting the Data for Training and Testing Purposes

# %%
from sklearn.model_selection import train_test_split

# test and train split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import GridSearchCV

# Decision Tree Regressor
dtr = DecisionTreeRegressor()

# hyperparameters
param_grid = {
    'max_depth': [2, 5, 10, 15, 20, 22],
    'min_samples_split': [2, 3, 4, 5],
    'min_samples_leaf': [2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20],
    'max_features': ['auto', 'sqrt', 'log2']
}

# gridsearchcv
grid_search = GridSearchCV(estimator=dtr, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)
print("Best hyperparameters:", grid_search.best_params_)
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# evalution metrics
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
print(" ")
print('Mean squared error:', mse)
print('Mean Absolute Error', mae)
print('Root Mean squared error:', rmse)
print(" ")
print('R-squared:', r2)

# %% [raw]
# Testing Our Trained Model (Decision Tree Regressor)

# %%
new_sample = np.array([[8740, 999, np.log(44), 55, np.log(11)]])
new_sample = scaler.transform(new_sample[:, :2])
new_pred = best_model.predict(new_sample)[0]
np.exp(new_pred)

# %%
# Saving the model
import pickle
with open('model.pkl', 'wb') as file:
    pickle.dump(best_model, file)
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

# %%
# !streamlit run singapore_resale.py

# %%
#!pip install geopy
